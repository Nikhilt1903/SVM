# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 1: Exploratory Data Analysis (EDA)

# %%
data=pd.read_csv("mushroom.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
data.describe(include=['O'])
# Out:
#        cap_shape cap_surface cap_color bruises  odor gill_attachment  \
# count       2000        2000      2000    2000  2000            2000
# unique         5           4         9       2     9               4
# top       sunken       scaly     brown     yes  foul            free
# freq         439         568       263    1023   274             540
#
#        gill_spacing gill_size gill_color stalk_shape  ...  \
# count          2000      2000       2000        2000  ...
# unique            3         2         12           2  ...
# top         distant    narrow     orange   enlarging  ...
# freq            677      1007        216        1040  ...
#
#        stalk_color_above_ring stalk_color_below_ring  veil_type veil_color  \
# count                    2000                   2000       2000       2000
# unique                      9                      9          2          4
# top                     brown                 orange  universal      white
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
#there are no null values

# %%
data.nunique()
# Out:
# Unnamed: 0                  976
# cap_shape                     5
# cap_surface                   4
# cap_color                     9
# bruises                       2
# odor                          9
# gill_attachment               4
# gill_spacing                  3
# gill_size                     2
# gill_color                   12
# stalk_shape                   2
# stalk_root                    7
# stalk_surface_above_ring      4
# stalk_surface_below_ring      4
# stalk_color_above_ring        9
# stalk_color_below_ring        9
# veil_type                     2
# veil_color                    4
# ring_number                   3
# ring_type                     8
# spore_print_color             9
# population                    6
# habitat                       7
# class                         2
# stalk_height                973
# cap_diameter                976
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Plotting histogram for numerical features
num_cols = ['stalk_height', 'cap_diameter']
data[num_cols].hist(bins=15, figsize=(10, 4), color='lightblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout()
plt.show()

# %%
#the data is uniformly distibuted

# %%
# Box plots for numerical columns
plt.figure(figsize=(12, 4))
for i, col in enumerate(num_cols):
    plt.subplot(1, 2, i+1)
    sns.boxplot(x=data[col], color='orange')
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
#no ouliers in the numerical data

# %%
# Plot frequency of some important categorical features
cat_cols = ['cap_shape', 'cap_surface', 'cap_color', 'odor', 'gill_color']

plt.figure(figsize=(15, 8))
for i, col in enumerate(cat_cols[:5]):
    plt.subplot(2, 3, i+1)
    sns.countplot(data=data, x=col, order=data[col].value_counts().index, palette='viridis')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/7r/nl1v4l8x65x2xn4dys5_1n4w0000gn/T/ipykernel_60445/3092162130.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=col, order=data[col].value_counts().index, palette='viridis')
# /var/folders/7r/nl1v4l8x65x2xn4dys5_1n4w0000gn/T/ipykernel_60445/3092162130.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=col, order=data[col].value_counts().index, palette='viridis')
# /var/folders/7r/nl1v4l8x65x2xn4dys5_1n4w0000gn/T/ipykernel_60445/3092162130.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Task 2: Data Preprocessing

# %%
#Encode categorical variables if necessary.
#we are label encoding the data as there are multiple fetures

from sklearn.preprocessing import LabelEncoder

#Initializing LabelEncoder
label_encoder = LabelEncoder()

for column in data.columns:
    if data[column].dtype == 'object':
        data[column] = label_encoder.fit_transform(data[column])

# %%
data.head()
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0          4            2          7        0     1                1
# 1          4            0          6        0     1                3
# 2          3            1          5        1     4                1
# 3          0            2          4        1     3                3
# 4          3            3          8        1     5                2
#
#    gill_spacing  gill_size  gill_color  stalk_shape  ...  veil_type  \
# 0             2          0           7            1  ...          0
# 1             1          1           3            0  ...          1
# 2             1          0           8            1  ...          1
# 3             0          0           6            0  ...          0
# 4             1          1           6            0  ...          1
#
#    veil_color  ring_number  ring_type  spore_print_color  population  habitat  \
# ...

# %%
#all the data is now encoded

# %%
#Split the dataset into training and testing sets.
#Features and target variable
x = data.drop(columns='class')
y = data['class']

# %%
from sklearn.model_selection import train_test_split

#Splitting the dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# # Task 3: Data Visualization

# %%
# Scatter plot between two continuous variables
sns.scatterplot(x='stalk_height', y='cap_diameter', data=data)
plt.title('Scatter Plot: Stalk Height vs Cap Diameter')
plt.xlabel('Stalk Height')
plt.ylabel('Cap Diameter')
plt.show()

# %%
#Visualize class distributions to gauge dataset balance or imbalance.
import seaborn as sns
import matplotlib.pyplot as plt

#Plotting class distribution
sns.countplot(data=data, x='class', palette='Set1')
plt.title("Mushroom Class Distribution: Edible vs Poisonous")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

print(data['class'].value_counts())
# Out:
# /var/folders/7r/nl1v4l8x65x2xn4dys5_1n4w0000gn/T/ipykernel_60445/2508140433.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='class', palette='Set1')
# 1    1400
# 0     600
# Name: class, dtype: int64

# %%
#this cleary shows imbalance in the dataset

# %%
#we are balaning =the imbalance using smote
from imblearn.over_sampling import SMOTE
#Applying smote only on training data
smote = SMOTE(random_state=42)
x_train_bal, y_train_bal = smote.fit_resample(x_train, y_train)

#Confirm the new class distribution
from collections import Counter
print("Before SMOTE:", Counter(y_train))
print("After SMOTE:", Counter(y_train_bal))
# Out:
# /Users/nikhil/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Before SMOTE: Counter({1: 1120, 0: 480})
# After SMOTE: Counter({1: 1120, 0: 1120})

# %%
import pandas as pd
sns.countplot(x=pd.Series(y_train_bal), palette='Set2')
plt.title("Balanced Class Distribution After SMOTE")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/7r/nl1v4l8x65x2xn4dys5_1n4w0000gn/T/ipykernel_60445/1131481592.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=pd.Series(y_train_bal), palette='Set2')

# %%
#the data is balanced

# %% [markdown]
# # Task 4: SVM Implementation

# %%
from sklearn.svm import SVC
#Initializing SVM classifier
svm_model = SVC(kernel='rbf', random_state=42)
#Train the model
svm_model.fit(x_train_bal, y_train_bal)
# Out:
# SVC(random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
#Making predictions
y_pred = svm_model.predict(x_test)

#Evaluating performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1 Score  : {f1:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy  : 0.6625
# Precision : 0.7656
# Recall    : 0.7464
# F1 Score  : 0.7559
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.47      0.45       120
#            1       0.77      0.75      0.76       280
#
#     accuracy                           0.66       400
#    macro avg       0.60      0.61      0.60       400
# weighted avg       0.67      0.66      0.67       400

# %%
#initially our model is shwing the accuracy of 66.25%

# %% [markdown]
# # Task 5: Visualization of SVM Results

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred)

#Plotting confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

#Printing classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.47      0.45       120
#            1       0.77      0.75      0.76       280
#
#     accuracy                           0.66       400
#    macro avg       0.60      0.61      0.60       400
# weighted avg       0.67      0.66      0.67       400

# %% [markdown]
# # Task 6: Parameter Tuning and Optimization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_bal_scaled = scaler.fit_transform(x_train_bal)
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.svm import SVC

# Define a smaller, faster hyperparameter space
param_dist = {
    'kernel': ['linear', 'rbf'],
    'C': uniform(0.1, 10),              # Randomly sample C from 0.1 to 10
    'gamma': ['scale', 0.01, 0.1, 1]    # Only applies to 'rbf'
}

# Setting up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=SVC(),
    param_distributions=param_dist,
    n_iter=10,                  # Only try 10 random combinations
    scoring='accuracy',
    cv=3,                       # 3-fold CV for speed
    random_state=42,
    n_jobs=-1,
    verbose=1
)

# Fit to training data
random_search.fit(X_train_bal_scaled, y_train_bal)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7fe07076ea90>,
#                                         'gamma': ['scale', 0.01, 0.1, 1],
#                                         'kernel': ['linear', 'rbf']},
#                    random_state=42, scoring='accuracy', verbose=1)

# %%
# Best parameters and score
print("Best Parameters:", random_search.best_params_)
print("Best Accuracy:", random_search.best_score_)

#Using the best model
best_svm = random_search.best_estimator_

#Predicting on test set
y_pred_opt = best_svm.predict(X_test_scaled)

#Evaluating
from sklearn.metrics import classification_report

print("\nClassification Report (Optimized SVM):")
print(classification_report(y_test, y_pred_opt))
# Out:
# Best Parameters: {'C': 8.424426408004217, 'gamma': 0.01, 'kernel': 'rbf'}
# Best Accuracy: 0.755390941185056
#
# Classification Report (Optimized SVM):
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52       120
#            1       0.79      0.82      0.81       280
#
#     accuracy                           0.73       400
#    macro avg       0.67      0.66      0.67       400
# weighted avg       0.72      0.73      0.72       400

# %%
#our accuracy of the model improved afetr parameter Tuning and Optimization

# %% [markdown]
# # Task 7: Comparison and Analysis

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train_bal)
X_test_scaled = scaler.transform(x_test)

#Define and evaluate models with different kernels
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
results = {}

for kernel in kernels:
    print(f"\nTraining SVM with {kernel} kernel...")
    model = SVC(kernel=kernel)
    model.fit(X_train_scaled, y_train_bal)
    y_pred = model.predict(X_test_scaled)

    # Evaluate
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    
    results[kernel] = {
        'accuracy': accuracy,
        'precision': report['weighted avg']['precision'],
        'recall': report['weighted avg']['recall'],
        'f1_score': report['weighted avg']['f1-score'],
        'report': classification_report(y_test, y_pred)
    }

#Displaying Results
print("\n SVM Kernel Comparison:")
print("{:<10} {:<10} {:<10} {:<10} {:<10}".format("Kernel", "Accuracy", "Precision", "Recall", "F1 Score"))
for kernel, metrics in results.items():
    print("{:<10} {:.4f}     {:.4f}     {:.4f}   {:.4f}".format(
        kernel, metrics['accuracy'], metrics['precision'], metrics['recall'], metrics['f1_score']))
# Out:
# Training SVM with linear kernel...
#
# Training SVM with poly kernel...
#
# Training SVM with rbf kernel...
#
# Training SVM with sigmoid kernel...
#
#  SVM Kernel Comparison:
# Kernel     Accuracy   Precision  Recall     F1 Score
# linear     0.6250     0.6375     0.6250   0.6305
# poly       0.8225     0.8177     0.8225   0.8183
# rbf        0.8075     0.8018     0.8075   0.8030
# sigmoid    0.4625     0.5288     0.4625   0.4845

# %%
#the poly model is giveing the best model performance

# %%
#Discuss practical implications of SVM in real-world classification tasks.

# %%
#svm can implied in
#medical diagnosis SVM is reliable for binary classification with high accuracy example if a patient has disease or not
#mage recognition RBF kernel is good for non-linear patterns in pixel-based data.
